# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
import yfinance as yf
ticker = "MSFT"
start_date = "2023-01-01"
end_date = "2023-07-31"

# Fetch historical data
data = yf.download(ticker, start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Split data into training and test set
train_size = int(0.8 * len(data))
train_data = data[:train_size]
test_data = data[train_size:]

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  243.080002  245.750000  237.399994  239.580002  237.956329
# 2023-01-04  232.279999  232.869995  225.960007  229.100006  227.547348
# 2023-01-05  227.199997  227.550003  221.759995  222.309998  220.803360
# 2023-01-06  223.000000  225.759995  219.350006  224.929993  223.405609
# 2023-01-09  226.449997  231.240005  226.410004  227.119995  225.580750
# ...                ...         ...         ...         ...         ...
# 2023-07-24  345.850006  346.920013  342.309998  345.109985  344.380859
# 2023-07-25  347.109985  351.890015  345.070007  350.980011  350.238464
# 2023-07-26  341.440002  344.670013  333.109985  337.769989  337.056366
# 2023-07-27  340.480011  341.329987  329.049988  330.720001  330.021271
# 2023-07-28  333.670013  340.010010  333.170013  338.369995  337.655090
#
#               Volume
# Date
# 2023-01-03  25740000
# 2023-01-04  50623400
# 2023-01-05  39585600
# 2023-01-06  43613600
# 2023-01-09  27369800
# ...              ...
# 2023-07-24  26678100
# 2023-07-25  41637700
# 2023-07-26  58383700
# 2023-07-27  39635300
# 2023-07-28  28484900
#
# [143 rows x 6 columns]

# %%
# Normalize the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data["Close"].values.reshape(-1, 1))
test_scaled = scaler.transform(test_data["Close"].values.reshape(-1, 1))

# %%
# Create LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(train_scaled.shape[1], 1)))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the LSTM model
model.fit(train_scaled, train_scaled, epochs=50, batch_size=16, verbose=1)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 0s 10ms/step - loss: 3.4012e-04
# Epoch 2/50
# 8/8 [==============================] - 0s 12ms/step - loss: 3.3715e-04
# Epoch 3/50
# 8/8 [==============================] - 0s 9ms/step - loss: 3.3086e-04
# Epoch 4/50
# 8/8 [==============================] - 0s 10ms/step - loss: 3.2499e-04
# Epoch 5/50
# 8/8 [==============================] - 0s 10ms/step - loss: 3.2491e-04
# Epoch 6/50
# 8/8 [==============================] - 0s 10ms/step - loss: 3.2767e-04
# Epoch 7/50
# 8/8 [==============================] - 0s 8ms/step - loss: 3.1887e-04
# Epoch 8/50
# 8/8 [==============================] - 0s 10ms/step - loss: 3.1409e-04
# Epoch 9/50
# 8/8 [==============================] - 0s 10ms/step - loss: 3.1271e-04
# Epoch 10/50
# 8/8 [==============================] - 0s 10ms/step - loss: 3.0779e-04
# Epoch 11/50
# 8/8 [==============================] - 0s 10ms/step - loss: 3.0875e-04
# Epoch 12/50
# 8/8 [==============================] - 0s 11ms/step - loss: 2.9832e-04
# Epoch 13/50
# 8/8 [==============================] - 0s 11ms/step - loss: 3.0288e-04
# Epoch 14/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.9141e-04
# Epoch 15/50
# 8/8 [==============================] - 0s 8ms/step - loss: 2.8899e-04
# Epoch 16/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.9191e-04
# Epoch 17/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.8110e-04
# Epoch 18/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.8503e-04
# Epoch 19/50
# 8/8 [==============================] - 0s 12ms/step - loss: 2.8306e-04
# Epoch 20/50
# 8/8 [==============================] - 0s 8ms/step - loss: 2.7288e-04
# Epoch 21/50
# 8/8 [==============================] - 0s 8ms/step - loss: 2.7110e-04
# Epoch 22/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.5895e-04
# Epoch 23/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.5584e-04
# Epoch 24/50
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6125e-04
# Epoch 25/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.5203e-04
# Epoch 26/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.4508e-04
# Epoch 27/50
# 8/8 [==============================] - 0s 18ms/step - loss: 2.5109e-04
# Epoch 28/50
# 8/8 [==============================] - 0s 11ms/step - loss: 2.4209e-04
# Epoch 29/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3619e-04
# Epoch 30/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3185e-04
# Epoch 31/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.2838e-04
# Epoch 32/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.2854e-04
# Epoch 33/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.2078e-04
# Epoch 34/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.2216e-04
# Epoch 35/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.1851e-04
# Epoch 36/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.1909e-04
# Epoch 37/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.1119e-04
# Epoch 38/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.1160e-04
# Epoch 39/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.1471e-04
# Epoch 40/50
# 8/8 [==============================] - 0s 11ms/step - loss: 2.0800e-04
# Epoch 41/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.0093e-04
# Epoch 42/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.8845e-04
# Epoch 43/50
# 8/8 [==============================] - 0s 11ms/step - loss: 1.9640e-04
# Epoch 44/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.8193e-04
# Epoch 45/50
# 8/8 [==============================] - 0s 11ms/step - loss: 1.8524e-04
# Epoch 46/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.7720e-04
# Epoch 47/50
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7819e-04
# Epoch 48/50
# 8/8 [==============================] - 0s 13ms/step - loss: 1.8643e-04
# Epoch 49/50
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7144e-04
# Epoch 50/50
# 8/8 [==============================] - 0s 11ms/step - loss: 1.7171e-04

# %%
# Evaluate the LSTM Model
test_inputs = test_scaled
predictions = model.predict(test_inputs)
predictions = scaler.inverse_transform(predictions)

# Calculate RMSE
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(test_data["Close"], predictions, squared=False)
print("Root Mean Squared Error:", rmse)
# Out:
# 1/1 [==============================] - 2s 2s/step
# Root Mean Squared Error: 2.922695557877062

# %%
from sklearn.metrics import mean_absolute_error

# Calculate MAE
mae = mean_absolute_error(test_data["Close"], predictions.reshape(-1))

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 2.704034213362069

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# Calculate MAPE
mape = mean_absolute_percentage_error(test_data["Close"], predictions.reshape(-1))

print("Mean Absolute Percentage Error:", mape)
# Out:
# Mean Absolute Percentage Error: 0.7890052742710293

# %%
# Make predictions
last_day_price = test_data.iloc[-1]["Close"]
last_day_scaled = scaler.transform(last_day_price.reshape(-1, 1))
prediction = model.predict(last_day_scaled)
predicted_price = scaler.inverse_transform(prediction)
print("Predicted Price:", predicted_price)
# Out:
# 1/1 [==============================] - 0s 43ms/step
# Predicted Price: [[340.76724]]

# %%
# Visualization 1: Original vs. Predicted Prices
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(test_data.index, test_data["Close"], label="Original Price", color="blue")
plt.plot(test_data.index, predictions, label="Predicted Price", color="orange")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.title("Original vs. Predicted Stock Prices")
plt.legend()
plt.show()

# %%
# Visualization 2: Loss Trend during Training
history = model.fit(train_scaled, train_scaled, epochs=50, batch_size=16, verbose=1)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label="Training Loss", color="blue")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Trend")
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.6580e-04
# Epoch 2/50
# 8/8 [==============================] - 0s 7ms/step - loss: 1.6339e-04
# Epoch 3/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.5707e-04
# Epoch 4/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.5300e-04
# Epoch 5/50
# 8/8 [==============================] - 0s 7ms/step - loss: 1.4958e-04
# Epoch 6/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.5693e-04
# Epoch 7/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.4277e-04
# Epoch 8/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.4412e-04
# Epoch 9/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.3975e-04
# Epoch 10/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.4578e-04
# Epoch 11/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.3727e-04
# Epoch 12/50
# 8/8 [==============================] - 0s 8ms/step - loss: 1.3046e-04
# Epoch 13/50
# 8/8 [==============================] - 0s 11ms/step - loss: 1.3393e-04
# Epoch 14/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.4349e-04
# Epoch 15/50
# 8/8 [==============================] - 0s 11ms/step - loss: 1.2692e-04
# Epoch 16/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.2623e-04
# Epoch 17/50
# 8/8 [==============================] - 0s 12ms/step - loss: 1.2882e-04
# Epoch 18/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.1831e-04
# Epoch 19/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1828e-04
# Epoch 20/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0943e-04
# Epoch 21/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1001e-04
# Epoch 22/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0375e-04
# Epoch 23/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0506e-04
# Epoch 24/50
# 8/8 [==============================] - 0s 11ms/step - loss: 1.0441e-04
# Epoch 25/50
# 8/8 [==============================] - 0s 9ms/step - loss: 9.7968e-05
# Epoch 26/50
# 8/8 [==============================] - 0s 8ms/step - loss: 9.4333e-05
# Epoch 27/50
# 8/8 [==============================] - 0s 9ms/step - loss: 9.2021e-05
# Epoch 28/50
# 8/8 [==============================] - 0s 9ms/step - loss: 9.1582e-05
# Epoch 29/50
# 8/8 [==============================] - 0s 7ms/step - loss: 9.0342e-05
# Epoch 30/50
# 8/8 [==============================] - 0s 9ms/step - loss: 8.8307e-05
# Epoch 31/50
# 8/8 [==============================] - 0s 10ms/step - loss: 8.3203e-05
# Epoch 32/50
# 8/8 [==============================] - 0s 9ms/step - loss: 8.3023e-05
# Epoch 33/50
# 8/8 [==============================] - 0s 10ms/step - loss: 8.0123e-05
# Epoch 34/50
# 8/8 [==============================] - 0s 11ms/step - loss: 7.8740e-05
# Epoch 35/50
# 8/8 [==============================] - 0s 10ms/step - loss: 7.8478e-05
# Epoch 36/50
# 8/8 [==============================] - 0s 11ms/step - loss: 7.6576e-05
# Epoch 37/50
# 8/8 [==============================] - 0s 9ms/step - loss: 7.1325e-05
# Epoch 38/50
# 8/8 [==============================] - 0s 11ms/step - loss: 7.1005e-05
# Epoch 39/50
# 8/8 [==============================] - 0s 11ms/step - loss: 6.8931e-05
# Epoch 40/50
# 8/8 [==============================] - 0s 15ms/step - loss: 6.7703e-05
# Epoch 41/50
# 8/8 [==============================] - 0s 11ms/step - loss: 7.5305e-05
# Epoch 42/50
# 8/8 [==============================] - 0s 11ms/step - loss: 7.0396e-05
# Epoch 43/50
# 8/8 [==============================] - 0s 10ms/step - loss: 6.2525e-05
# Epoch 44/50
# 8/8 [==============================] - 0s 10ms/step - loss: 6.1075e-05
# Epoch 45/50
# 8/8 [==============================] - 0s 9ms/step - loss: 5.8812e-05
# Epoch 46/50
# 8/8 [==============================] - 0s 8ms/step - loss: 5.6935e-05
# Epoch 47/50
# 8/8 [==============================] - 0s 9ms/step - loss: 5.7651e-05
# Epoch 48/50
# 8/8 [==============================] - 0s 11ms/step - loss: 5.2670e-05
# Epoch 49/50
# 8/8 [==============================] - 0s 9ms/step - loss: 5.1510e-05
# Epoch 50/50
# 8/8 [==============================] - 0s 10ms/step - loss: 6.2747e-05

# %%
# Visualization 3: Predicted Price Distribution
plt.figure(figsize=(10, 6))
plt.hist(predictions, bins=30, color="purple", edgecolor="black")
plt.xlabel("Predicted Stock Price")
plt.ylabel("Frequency")
plt.title("Distribution of Predicted Stock Prices")
plt.show()

# %%
# Visualization 4: Price Trend with Training and Test Data
plt.figure(figsize=(12, 6))
plt.plot(train_data.index, train_data["Close"], label="Training Data", color="blue")
plt.plot(test_data.index, test_data["Close"], label="Test Data", color="green")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.title("Stock Price Trend with Training and Test Data")
plt.legend()
plt.show()

# %%
# Residual Plot Visualization
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Calculate residuals
residuals = test_data["Close"] - predictions[:, 0]

# Create the scatter plot
plt.scatter(test_data.index, residuals, color="red", alpha=0.5, marker='o', s=50, label="Residuals")

# Add a horizontal line at y=0
plt.axhline(y=0, color='black', linestyle='--', label="Residual = 0")

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Add labels and title
plt.xlabel("Date")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.legend()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Actual vs. Predicted Prices (Zoomed-in)
zoom_start_date = "2023-06-01"
zoom_end_date = "2023-07-31"
zoom_data = test_data[(test_data.index >= zoom_start_date) & (test_data.index <= zoom_end_date)]

plt.figure(figsize=(12, 6))
plt.plot(zoom_data.index, zoom_data["Close"], label="Actual Price", color="blue")
plt.plot(zoom_data.index, predictions[-len(zoom_data):], label="Predicted Price", color="orange")
plt.fill_between(zoom_data.index, predictions[-len(zoom_data):, 0] - rmse, predictions[-len(zoom_data):, 0] + rmse, color='orange', alpha=0.2, label="Prediction Error")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.title("Actual vs. Predicted Stock Prices (Zoomed-in)")
plt.legend()
plt.show()

# %%
# Performance Metrics Comparison
metric_names = ["RMSE", "MAE", "MAPE"]
metric_values = [rmse, mae, mape]

plt.figure(figsize=(10, 6))
plt.bar(metric_names, metric_values, color=["blue", "green", "purple"])
plt.xlabel("Metrics")
plt.ylabel("Value")
plt.title("Performance Metrics Comparison")
plt.show()
